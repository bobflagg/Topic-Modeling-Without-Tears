# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import matplotlib.pyplot as plt
# %matplotlib inline  

import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from tmwt.corpus import Builder
from tmwt.util import *

# %%
import gensim
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models.wrappers import LdaMallet
from gensim.models.wrappers.ldamallet import malletmodel2ldamodel
from gensim import similarities
from nltk.tokenize import sent_tokenize, word_tokenize
import random

# %% [markdown]
# ## 1. Building the WikiPedia Corpus

# %%
# %%time
records = load_records(path='/opt/code/github/Topic-Modeling-Without-Tears/data/kb-50K.tsv')
texts = [text for record_id, text in records]
print("# records:", len(records))
# Out:
# Loaded 116231 records with 25236 errors.
# CPU times: user 21.6 s, sys: 248 ms, total: 21.9 s
# Wall time: 22 s

# %%
# %%time

REFRESH = True

builder = Builder(
    ndocs=len(texts),
    phrase_min_count=3, 
    vocabulary_size=10000,
    bigram_min_count=3,
    bigram_threshold=10,
    trigram_min_count=3,
    trigram_threshold=10,
    data_directory=DATA_DIRECTORY,
    model_directory=MODEL_DIRECTORY
)
if REFRESH:
    builder.train_phrasers(texts)    
    builder.save_phrasers()
    prepared_texts = builder.prepare_texts(texts)
    builder.build_vocabulary(prepared_texts, save=True)
    corpus = builder.build_corpus(prepared_texts)
    builder.build_dictionary(corpus, save=True)
builder.load_phrasers()
builder.load_vocabulary()
builder.load_dictionary()
encoded_corpus = builder.encode_corpus(corpus)

builder.save_dictionary(path=DICTIONARY_PATH)
# Out:
# Streaming text for bigram phraser  ...: 100%|██████████| 116231/116231 [03:26<00:00, 562.03it/s]
# Streaming text for trigram phraser ...: 100%|██████████| 116231/116231 [04:53<00:00, 395.94it/s]
# Preparing texts ...: 100%|██████████| 116231/116231 [04:15<00:00, 454.52it/s]
# Building vocabulary over 116231 documents.: 100%|██████████| 116231/116231 [00:04<00:00, 27510.04it/s]
# Building corpus ...: 100%|██████████| 116231/116231 [00:03<00:00, 35018.70it/s]
# CPU times: user 14min 26s, sys: 11.2 s, total: 14min 37s
# Wall time: 14min 39s

# %% [markdown]
# ## 2. Train a Topic Model

# %%
# %%time

num_topics = 128
model = LdaMallet(
    mallet_path=MALLET_PATH, 
    corpus=encoded_corpus,
    num_topics=num_topics, 
    id2word=builder.dictionary
)

model.save(MALLET_MODEL_PATH)
# Out:
# CPU times: user 20.5 s, sys: 613 ms, total: 21.2 s
# Wall time: 6min 19s

# %%
dictionary = Dictionary.load(DICTIONARY_PATH) 
model = LdaMallet.load(MALLET_MODEL_PATH)
show_topic_model(model, dictionary, use_phrasers=True)
# Out:
# Topic 0:
#   including, include, includes, major, numerous, number, primarily, notable, addition, campbell
#   as_well_as, a_variety, addition_to, there_are, many_other, several_other
# Topic 1:
#   form, similar, forms, structure, called, type, single, common, found, include
#   they_are, such_as, there_are, each_other, also_called, rather_than
# Topic 2:
#   television, radio, show, network, channel, broadcast, bbc, tv, shows, live
#   owned_by, broadcast_on, hosted_by, is_an_american, radio_station, radio_stations
# Topic 3:
#   greek, africa, turkey, country, egypt, greece, african, lebanon, turkish, syria
#   middle_east, north_africa, ottoman_empire, as_well_as, west_africa, due_to
# Topic 4:
#   earth, sun, space, star, moon, stars, light, mass, surface, mission
#   to_be, solar_system, named_after, away_from, due_to, larger_than
# Topic 5:
#   country, iraq, status, citizens, free, countries, official, issued, registered, passport
#   saudi_arabia, according_to, united_arab_emirates, to_be, as_well_as, there_are
# Topic 6:
#   park, site, located, area, centre, home, castle, hill, open, public
#   managed_by, adjacent_to, state_park, owned_by, an_area, national_park
# Topic 7:
#   massachusetts, connecticut, boston, maine, named, american, part, vermont, home, center
#   united_states, new_england, new_hampshire, rhode_island, known_for, along_with
# Topic 8:
#   people, gay, subject, view, true, evidence, question, found, reason, fact
#   to_be, have_been, should_be, did_not, rather_than, according_to
# Topic 9:
#   culture, modern, traditional, style, developed, early, today, influence, elements, cultural
#   such_as, as_well_as, influenced_by, associated_with, 19th_century, 20th_century
# Topic 10:
#   land, people, established, today, colony, history, settlement, nation, settled, early
#   19th_century, known_as, native_american, they_were, 18th_century, 20th_century
# Topic 11:
#   university, college, institute, campus, professor, school, research, universities, founded, students
#   higher_education, law_school, main_campus, medical_school, state_university, public_university
# Topic 12:
#   board, business, management, services, work, service, public, chairman, professional, director
#   responsible_for, chief_executive_officer, on_behalf, addition_to, a_wide_range, executive_director
# Topic 13:
#   district, part, western, central, eastern, southern, northern, parts, includes, czech
#   czech_republic, also_known_as, rural_district, also_includes, which_includes, united_states_district_court
# Topic 14:
#   war, battle, army, forces, british, fought, campaign, captured, troops, attack
#   world_war_ii, led_by, took_place, world_war_i, second_world_war, first_world_war
# Topic 15:
#   announced, future, proposed, decided, planned, plan, decision, began, result, plans
#   would_be, to_be, had_been, announced_that, due_to, will_be
# Topic 16:
#   school, education, students, schools, college, located, academy, program, student, classes
#   high_school, school_district, public_schools, public_high_school, secondary_school, public_school
# Topic 17:
#   women, israel, men, jewish, jews, male, including, female, jerusalem, jordan
#   according_to, to_be, has_been, known_as, also_known_as, west_bank
# Topic 18:
#   population, people, country, majority, live, living, largest, million, communities, community
#   according_to, there_are, there_were, more_than, total_population, sierra_leone
# Topic 19:
#   american, chicago, america, illinois, minnesota, missouri, wisconsin, iowa, lincoln, nebraska
#   united_states, kansas_city, mississippi_river, great_lakes, an_american, saint_paul
# Topic 20:
#   season, team, university, games, conference, ncaa, represented, oklahoma, member, played
#   head_coach, played_their_home, national_championship, college_football, ncaa_division_i, regular_season
# Topic 21:
#   military, army, command, units, force, rank, unit, police, service, chief
#   air_force, armed_forces, united_states_army, national_guard, british_army, responsible_for
# Topic 22:
#   russia, russian, ii, poland, operation, polish, soviet, ukraine, moscow, german
#   soviet_union, during_world_war, world_war_ii, after_world_war, nazi_germany, russian_empire
# Topic 23:
#   france, french, germany, german, paris, austria, switzerland, serbia, berlin, de
#   west_germany, federal_republic, east_germany, de_la, french_revolution, world_war_i
# Topic 24:
#   british, ireland, uk, irish, britain, dublin, london, hungarian, belfast, cork
#   united_kingdom, great_britain, northern_ireland, an_irish, british_empire, british_isles
# Topic 25:
#   music, rock, performed, musical, composer, jazz, dance, sound, blues, orchestra
#   classical_music, popular_music, folk_music, rock_music, pop_music, hip_hop
# Topic 26:
#   race, season, won, held, races, racing, circuit, championship, points, driver
#   grand_prix, world_championship, formula_one, formula_one_motor_race, formula_one_season, tour_de_france
# Topic 27:
#   international, european, europe, dutch, netherlands, belgium, treaty, countries, signed, agreement
#   european_union, united_nations, as_well_as, member_states, united_kingdom, together_with
# Topic 28:
#   china, people, chinese, republic, taiwan, romania, vietnam, bulgaria, romanian, albania
#   hong_kong, as_well_as, mainland_china, north_macedonia, communist_party, commonly_known_as
# Topic 29:
#   india, pakistan, indian, singapore, malaysia, indonesia, thailand, country, bangladesh, nepal
#   south_africa, sri_lanka, south_african, an_indian, indian_subcontinent, also_known_as
# Topic 30:
#   model, car, design, production, engine, models, produced, cars, ford, vehicles
#   based_on, produced_by, manufactured_by, powered_by, general_motors, designed_by
# Topic 31:
#   city, population, capital, located, home, cities, area, center, largest, municipality
#   metropolitan_area, largest_city, county_seat, 2010_census, making_it, capital_city
# Topic 32:
#   series, character, show, episode, characters, episodes, season, appeared, comics, original
#   created_by, television_series, a_fictional_character, first_appeared, based_on, portrayed_by
# Topic 33:
#   current, past, including, times, present, remains, date, created, holds, recently
#   has_been, have_been, as_well_as, since_then, also_been, due_to
# Topic 34:
#   time, made, back, end, making, move, place, set, point, rest
#   to_make, to_be, more_than, to_take, as_well, so_that
# Topic 35:
#   fame, played, player, coach, hall, named, selected, career, players, nba
#   is_an_american, national_basketball_association, head_coach, his_career, where_he, was_inducted_into
# Topic 36:
#   town, village, population, located, area, county, part, parish, municipality, north
#   2010_census, named_after, civil_parish, is_situated, 2011_census, 2000_census
# Topic 37:
#   god, religion, islam, religious, christian, jesus, muslims, islamic, muslim, christianity
#   according_to, based_on, new_testament, to_be, such_as, believed_to
# Topic 38:
#   government, president, head, minister, office, ministry, position, appointed, cabinet, post
#   prime_minister, responsible_for, was_appointed, headed_by, foreign_affairs, vice_president
# Topic 39:
#   magazine, media, published, newspaper, news, paper, website, press, editor, daily
#   published_by, new_york_times, according_to, focused_on, social_media, owned_by
# Topic 40:
#   community, township, pennsylvania, ohio, located, philadelphia, population, named, cleveland, part
#   united_states, new_jersey, is_an_unincorporated, post_office, 2010_census, 2000_census
# Topic 41:
#   won, title, final, championship, winning, reached, defeated, lost, win, titles
#   to_win, first_time, first_round, world_no, second_round, first_time_since
# Topic 42:
#   white, black, red, green, flag, blue, arms, color, brown, cross
#   to_represent, national_flag, also_known_as, reference_to, based_on, they_were
# Topic 43:
#   group, california, groups, nevada, based, berkeley, members, american, oakland, ca
#   los_angeles, san_francisco, united_states, san_diego, known_for, is_an_american
# Topic 44:
#   art, museum, work, works, collection, library, artist, arts, artists, painting
#   his_work, as_well_as, fine_arts, natural_history, inspired_by, national_museum
# Topic 45:
#   road, street, bridge, highway, route, section, avenue, neighborhood, north, runs
#   state_highway, passes_through, main_street, designated_as, state_route, east_side
# Topic 46:
#   kingdom, period, empire, roman, power, emperor, bc, rule, history, dynasty
#   middle_ages, ruled_by, roman_empire, ottoman_empire, byzantine_empire, 15th_century
# Topic 47:
#   oregon, american, including, portland, part, brooklyn, manhattan, buffalo, jamaica, rochester
#   new_york, new_york_city, united_states, is_an_american, an_american, long_island
# Topic 48:
#   australia, australian, victoria, sydney, melbourne, queensland, suburb, adelaide, perth, brisbane
#   new_south_wales, is_an_australian, western_australia, south_australia, an_australian, papua_new_guinea
# Topic 49:
#   book, published, author, books, works, writer, work, literature, story, writing
#   science_fiction, has_written, he_wrote, published_by, short_stories, his_work
# Topic 50:
#   development, project, program, health, support, environment, provide, resources, policy, projects
#   access_to, to_improve, to_promote, to_develop, to_create, health_care
# Topic 51:
#   typically, process, specific, person, generally, rules, individual, practice, provide, case
#   such_as, may_be, can_be, for_example, or_more, they_are
# Topic 52:
#   small, long, large, body, size, smaller, length, wood, called, similar
#   also_known_as, attached_to, also_called, can_be, could_be, to_create
# Topic 53:
#   house, members, council, parliament, elected, member, election, seat, assembly, representatives
#   legislative_assembly, national_assembly, legislative_council, lower_house, upper_house, general_election
# Topic 54:
#   team, played, football, teams, players, international, rugby, sport, competition, play
#   world_cup, national_team, rugby_union, they_have, is_controlled_by, national_football_team
# Topic 55:
#   march, january, october, early, april, september, june, august, december, november
#   that_year, followed_by, had_been, same_year, following_year, returned_to
# Topic 56:
#   term, terms, word, meaning, concept, form, means, generally, specific, applied
#   refers_to, such_as, to_refer_to, derived_from, refer_to, for_example
# Topic 57:
#   year, day, held, festival, days, events, years, date, night, beginning
#   each_year, every_year, gregorian_calendar, an_annual, takes_place, to_celebrate
# Topic 58:
#   world, history, including, greatest, oldest, major, global, ranked, worldwide, considered
#   has_been, as_well_as, more_than, all_time, considered_one, most_famous
# Topic 59:
#   church, christian, temple, catholic, churches, utah, mission, members, christ, religious
#   catholic_church, jesus_christ, roman_catholic, salt_lake_city, known_as, roman_catholic_church
# Topic 60:
#   spain, spanish, mexico, de, brazil, argentina, brazilian, chile, caribbean, mexican
#   puerto_rico, latin_america, south_america, buenos_aires, mexico_city, costa_rica
# Topic 61:
#   part, major, called, formed, minor, key, included, main, originally, principal
#   known_as, also_known_as, along_with, has_been, often_referred_to, or_simply
# Topic 62:
#   1980s, 1970s, 1990s, began, 1960s, 1950s, early, success, 1930s, continued
#   20th_century, early_1990s, late_1960s, late_1980s, early_1970s, late_1990s
# Topic 63:
#   island, bay, islands, sea, colorado, point, beach, coast, part, peninsula
#   new_mexico, pacific_ocean, atlantic_ocean, east_coast, an_area, west_coast
# Topic 64:
#   class, ship, ships, built, service, navy, uss, fleet, launched, commissioned
#   royal_navy, united_states_navy, launched_on, during_world_war, world_war_ii, named_after
# Topic 65:
#   season, team, nfl, game, playoffs, record, games, nhl, franchise, played
#   national_football_league, national_hockey_league, regular_season, super_bowl, he_played_college, former_american_football
# Topic 66:
#   john, david, michael, paul, robert, wilson, bell, mark, miller, thompson
#   is_an_american, best_known_for, is_best_known, known_for, has_worked, also_worked
# Topic 67:
#   film, films, theatre, actor, director, movie, actress, television, producer, role
#   directed_by, is_an_american, produced_by, based_on, was_nominated_for, same_name
# Topic 68:
#   club, played, season, manager, side, league, appearances, goals, liverpool, playing
#   football_league, fa_cup, premier_league, manchester_united, who_played, where_he
# Topic 69:
#   fire, caused, people, occurred, damage, storm, killed, deaths, hurricane, time
#   due_to, at_least, there_were, caused_by, tropical_storm, more_than
# Topic 70:
#   energy, water, power, material, form, ice, gas, process, heat, temperature
#   such_as, can_be, to_produce, natural_gas, can_also, also_called
# Topic 71:
#   age, time, years, life, made, young, jones, early, started, working
#   along_with, to_become, two_years, an_early, three_years, moved_to
# Topic 72:
#   king, son, duke, prince, charles, henry, title, william, lord, house
#   his_father, his_son, until_his_death, was_succeeded_by, his_death, his_brother
# Topic 73:
#   game, released, games, series, version, features, original, release, development, versions
#   based_on, developed_by, published_by, video_game, video_games, such_as
# Topic 74:
#   won, record, gold, silver, held, contest, competition, winning, set, championships
#   gold_medal, world_championships, bronze_medal, to_win, silver_medal, most_successful
# Topic 75:
#   family, children, married, child, daughter, mother, marriage, wife, father, queen
#   was_born, his_wife, her_husband, where_she, her_father, they_had
# Topic 76:
#   japan, japanese, europe, world, asia, born, tokyo, korea, including, korean
#   north_america, south_korea, also_known_as, as_well_as, known_as, has_been
# Topic 77:
#   washington, georgia, virginia, alabama, louisiana, indiana, mississippi, columbia, seattle, atlanta
#   united_states, north_carolina, south_carolina, new_orleans, west_virginia, george_washington
# Topic 78:
#   airport, port, aircraft, air, base, located, largest, flight, passengers, international
#   international_airport, operated_by, serves_as, royal_air_force, as_well_as, formerly_known_as
# Topic 79:
#   original, system, created, changed, introduced, replaced, originally, added, separate, initially
#   prior_to, replaced_by, was_renamed, had_been, was_replaced_by, along_with
# Topic 80:
#   james, smith, george, john, martin, scott, taylor, jack, joe, tom
#   an_american, best_known_for, is_an_american, his_brother, who_worked, other_notable
# Topic 81:
#   man, made, great, johnson, good, called, time, big, famous, popular
#   known_for, his_own, most_famous, well_known, to_keep, man_who
# Topic 82:
#   north, south, west, east, located, area, northwest, northeast, southwest, border
#   it_is_bordered, is_bounded_by, is_bordered_by, as_far, an_area, southern_part
# Topic 83:
#   law, act, constitution, laws, government, rights, legal, states, bill, passed
#   human_rights, federal_government, accordance_with, approved_by, international_law, to_protect
# Topic 84:
#   disease, treatment, blood, body, medical, people, cells, include, cancer, human
#   such_as, also_known_as, may_be, associated_with, due_to, caused_by
# Topic 85:
#   river, lake, water, valley, mountain, mountains, range, rivers, area, creek
#   national_park, mountain_range, national_forest, state_park, named_after, red_river
# Topic 86:
#   union, general, tennessee, lee, rose, jackson, grant, end, position, memphis
#   american_civil_war, along_with, civil_war, served_as, to_become, prior_to
# Topic 87:
#   state, department, states, federal, commonwealth, idaho, governor, montana, secretary, wyoming
#   north_dakota, south_dakota, responsible_for, united_states, united_states_department, federal_government
# Topic 88:
#   government, independence, country, republic, afghanistan, led, power, revolution, war, support
#   united_nations, led_by, civil_war, democratic_republic, two_countries, relations_with
# Topic 89:
#   political, movement, social, society, freedom, economic, groups, politics, people, cultural
#   such_as, human_rights, based_on, civil_rights, focused_on, rather_than
# Topic 90:
#   london, england, oxford, birmingham, kent, cambridge, bristol, english, surrey, essex
#   was_an_english, united_kingdom, an_english, london_borough, south_west, river_thames
# Topic 91:
#   english, language, languages, written, names, standard, words, latin, spoken, modern
#   derived_from, such_as, based_on, spoken_by, official_language, english_language
# Topic 92:
#   florida, michigan, named, detroit, williams, kansas, alaska, miami, member, bush
#   united_states, is_an_american, is_best_known, as_well_as, an_american, served_as
# Topic 93:
#   party, election, leader, seats, won, held, elections, vote, majority, government
#   political_party, led_by, general_election, liberal_party, labour_party, democratic_party
# Topic 94:
#   data, software, systems, system, computer, information, microsoft, internet, support, technology
#   such_as, operating_system, based_on, developed_by, operating_systems, can_be
# Topic 95:
#   died, member, born, son, william, age, john, thomas, worked, director
#   was_born, where_he, he_died, was_appointed, he_worked, his_life
# Topic 96:
#   italy, italian, diocese, bishop, cathedral, rome, part, milan, abbey, city
#   an_italian, dedicated_to, serie_a, roman_catholic_diocese, roman_catholic_church, roman_catholic_archdiocese
# Topic 97:
#   bank, money, market, price, banks, financial, exchange, property, sale, tax
#   real_estate, central_bank, stock_exchange, national_bank, to_buy, financial_services
# Topic 98:
#   texas, stadium, home, center, located, arena, opened, capacity, field, houston
#   moved_to, san_antonio, formerly_known_as, owned_by, operated_by, also_hosted
# Topic 99:
#   song, single, released, number, featured, version, included, recorded, performed, video
#   written_by, produced_by, billboard_hot_100, uk_singles_chart, music_video, top_ten
# Topic 100:
#   played, play, game, test, ball, match, cricket, lead, players, runs
#   west_indies, who_played, county_championship, to_take, cricket_club, he_scored
# Topic 101:
#   season, team, record, games, played, baseball, game, series, al, franchise
#   national_league, world_series, major_league_baseball, american_league, new_york_yankees, major_league
# Topic 102:
#   division, fourth, place, arizona, total, ten, top, 2nd, seventh, sixth
#   first_time, along_with, prior_to, tied_for, top_three, one_point
# Topic 103:
#   main, part, including, local, portugal, portuguese, made, hamilton, included, ring
#   new_zealand, known_as, as_well_as, due_to, they_were, commonly_known_as
# Topic 104:
#   national, association, members, member, organization, founded, international, federation, society, organisation
#   affiliated_with, a_founding_member, an_independent, scout_movement, formerly_known_as, governing_body
# Topic 105:
#   region, province, area, regions, areas, provinces, territory, capital, cities, municipalities
#   an_area, divided_into, local_government, there_are, defined_by, administered_by
# Topic 106:
#   elected, governor, president, member, representatives, republican, house, senate, congress, office
#   he_served_as, served_as, united_states_house, vice_president, he_served, to_serve
# Topic 107:
#   number, list, including, iran, included, numbers, total, hawaii, code, call
#   based_on, according_to, also_known_as, as_well_as, has_been, more_than
# Topic 108:
#   canada, canadian, ontario, toronto, quebec, province, alberta, montreal, vancouver, manitoba
#   british_columbia, nova_scotia, new_brunswick, legislative_assembly, canadian_province, prince_edward_island
# Topic 109:
#   world, economy, country, largest, industry, agriculture, trade, production, oil, major
#   according_to, second_largest, economic_growth, more_than, world_bank, natural_resources
# Topic 110:
#   high, low, increased, level, increase, higher, rate, lack, average, levels
#   due_to, compared_to, expected_to, to_be, ability_to, at_least
# Topic 111:
#   system, set, function, unit, method, problem, point, mathematics, object, values
#   for_example, can_be, based_on, defined_as, an_object, may_be
# Topic 112:
#   court, case, justice, judge, prison, trial, murder, police, courts, crime
#   supreme_court, chief_justice, had_been, was_arrested, high_court, charged_with
# Topic 113:
#   company, founded, corporation, companies, sold, brand, business, products, subsidiary, largest
#   owned_by, merged_with, was_acquired_by, purchased_by, brand_name, listed_on
# Topic 114:
#   award, received, awarded, awards, won, year, national, presented, prize, academy
#   have_won, has_been, known_for, for_his_work, each_year, that_year
# Topic 115:
#   games, sports, events, sport, athletes, held, event, total, compete, competed
#   olympic_games, competed_at, first_time, were_held, took_part, 2008_summer_olympics
# Topic 116:
#   line, station, railway, service, lines, opened, trains, served, services, stations
#   railway_station, operated_by, main_line, public_transport, railway_line, it_serves
# Topic 117:
#   england, scotland, wales, scottish, english, welsh, manchester, glasgow, leeds, edinburgh
#   united_kingdom, north_west, greater_manchester, west_yorkshire, great_britain, north_east
# Topic 118:
#   album, band, released, records, release, recorded, albums, songs, label, group
#   is_an_american, rock_band, all_time, record_producer, billboard_200, record_label
# Topic 119:
#   building, built, buildings, construction, house, tower, located, architecture, completed, houses
#   designed_by, city_hall, town_hall, to_build, were_built, historic_district
# Topic 120:
#   sweden, philippines, norway, part, denmark, swedish, national, finland, norwegian, danish
#   as_well_as, has_been, also_known_as, along_with, together_with, faroe_islands
# Topic 121:
#   club, league, season, division, teams, clubs, football, team, founded, based
#   football_club, football_league, second_division, have_won, premier_league, they_play
# Topic 122:
#   county, maryland, population, kentucky, properties, districts, counties, named, arkansas, list
#   national_register, 2010_census, united_states, historic_places, county_located, its_county_seat
# Topic 123:
#   left, end, began, lost, joined, remained, return, continued, eventually, back
#   had_been, returned_to, who_had, they_were, to_become, this_time
# Topic 124:
#   order, considered, called, time, made, thought, earlier, complete, proved, superior
#   to_be, they_were, known_as, according_to, have_been, to_make
# Topic 125:
#   species, food, found, family, animals, native, fish, tree, plant, plants
#   such_as, they_are, have_been, years_ago, derived_from, ranging_from
# Topic 126:
#   tournament, held, final, competition, won, played, event, championship, cup, open
#   ended_on, took_place, singles_title, defending_champions, took_place_at, played_on_outdoor
# Topic 127:
#   study, research, science, field, theory, philosophy, development, studies, fields, work
#   concerned_with, deals_with, to_understand, focused_on, based_on, nobel_prize

# %%
lda = malletmodel2ldamodel(model, gamma_threshold=0.001, iterations=50)
lda.save(GENSIM_MODEL_PATH)
lda = LdaModel.load(GENSIM_MODEL_PATH)
show_topic_lda(lda, dictionary, use_phrasers=True)
# Out:
# Topic 0:
#   including, include, includes, major, numerous, number, primarily, notable, addition, campbell
#   as_well_as, a_variety, addition_to, there_are, many_other, several_other
# Topic 1:
#   form, similar, forms, structure, called, type, single, common, found, include
#   they_are, such_as, there_are, each_other, also_called, rather_than
# Topic 2:
#   television, radio, show, network, channel, broadcast, bbc, tv, shows, live
#   owned_by, broadcast_on, hosted_by, is_an_american, radio_station, radio_stations
# Topic 3:
#   greek, africa, turkey, country, egypt, greece, african, lebanon, turkish, syria
#   middle_east, north_africa, ottoman_empire, as_well_as, west_africa, due_to
# Topic 4:
#   earth, sun, space, star, moon, stars, light, mass, surface, mission
#   to_be, solar_system, named_after, away_from, due_to, larger_than
# Topic 5:
#   country, iraq, status, citizens, free, countries, official, issued, registered, passport
#   saudi_arabia, according_to, united_arab_emirates, to_be, as_well_as, there_are
# Topic 6:
#   park, site, located, area, centre, home, castle, hill, open, public
#   managed_by, adjacent_to, state_park, owned_by, an_area, national_park
# Topic 7:
#   massachusetts, connecticut, boston, maine, named, american, part, vermont, home, center
#   united_states, new_england, new_hampshire, rhode_island, known_for, along_with
# Topic 8:
#   people, gay, subject, view, true, evidence, question, found, reason, fact
#   to_be, have_been, should_be, did_not, rather_than, according_to
# Topic 9:
#   culture, modern, traditional, style, developed, early, today, influence, elements, cultural
#   such_as, as_well_as, influenced_by, associated_with, 19th_century, 20th_century
# Topic 10:
#   land, people, established, today, colony, history, settlement, nation, settled, early
#   19th_century, known_as, native_american, they_were, 18th_century, 20th_century
# Topic 11:
#   university, college, institute, campus, professor, school, research, universities, founded, students
#   higher_education, law_school, main_campus, medical_school, state_university, public_university
# Topic 12:
#   board, business, management, services, work, service, public, chairman, professional, director
#   responsible_for, chief_executive_officer, on_behalf, addition_to, a_wide_range, executive_director
# Topic 13:
#   district, part, western, central, eastern, southern, northern, parts, includes, czech
#   czech_republic, also_known_as, rural_district, also_includes, which_includes, united_states_district_court
# Topic 14:
#   war, battle, army, forces, british, fought, campaign, captured, troops, attack
#   world_war_ii, led_by, took_place, world_war_i, second_world_war, first_world_war
# Topic 15:
#   announced, future, proposed, decided, planned, plan, decision, began, result, plans
#   would_be, to_be, had_been, announced_that, due_to, will_be
# Topic 16:
#   school, education, students, schools, college, located, academy, program, student, classes
#   high_school, school_district, public_schools, public_high_school, secondary_school, public_school
# Topic 17:
#   women, israel, men, jewish, jews, male, including, female, jerusalem, jordan
#   according_to, to_be, has_been, known_as, also_known_as, west_bank
# Topic 18:
#   population, people, country, majority, live, living, largest, million, communities, community
#   according_to, there_are, there_were, more_than, total_population, sierra_leone
# Topic 19:
#   american, chicago, america, illinois, minnesota, missouri, wisconsin, iowa, lincoln, nebraska
#   united_states, kansas_city, mississippi_river, great_lakes, an_american, saint_paul
# Topic 20:
#   season, team, university, games, conference, ncaa, represented, oklahoma, member, played
#   head_coach, played_their_home, national_championship, college_football, ncaa_division_i, regular_season
# Topic 21:
#   military, army, command, units, force, rank, unit, police, service, chief
#   air_force, armed_forces, united_states_army, national_guard, british_army, responsible_for
# Topic 22:
#   russia, russian, ii, poland, operation, polish, soviet, ukraine, moscow, german
#   soviet_union, during_world_war, world_war_ii, after_world_war, nazi_germany, russian_empire
# Topic 23:
#   france, french, germany, german, paris, austria, switzerland, serbia, berlin, de
#   west_germany, federal_republic, east_germany, de_la, french_revolution, world_war_i
# Topic 24:
#   british, ireland, uk, irish, britain, dublin, london, hungarian, belfast, cork
#   united_kingdom, great_britain, northern_ireland, an_irish, british_empire, british_isles
# Topic 25:
#   music, rock, performed, musical, composer, jazz, dance, sound, blues, orchestra
#   classical_music, popular_music, folk_music, rock_music, pop_music, hip_hop
# Topic 26:
#   race, season, won, held, races, racing, circuit, championship, points, driver
#   grand_prix, world_championship, formula_one, formula_one_motor_race, formula_one_season, tour_de_france
# Topic 27:
#   international, european, europe, dutch, netherlands, belgium, treaty, countries, signed, agreement
#   european_union, united_nations, as_well_as, member_states, united_kingdom, together_with
# Topic 28:
#   china, people, chinese, republic, taiwan, romania, vietnam, bulgaria, romanian, albania
#   hong_kong, as_well_as, mainland_china, north_macedonia, communist_party, commonly_known_as
# Topic 29:
#   india, pakistan, indian, singapore, malaysia, indonesia, thailand, country, bangladesh, nepal
#   south_africa, sri_lanka, south_african, an_indian, indian_subcontinent, also_known_as
# Topic 30:
#   model, car, design, production, engine, models, produced, cars, ford, vehicles
#   based_on, produced_by, manufactured_by, powered_by, general_motors, designed_by
# Topic 31:
#   city, population, capital, located, home, cities, area, center, largest, municipality
#   metropolitan_area, largest_city, county_seat, 2010_census, making_it, capital_city
# Topic 32:
#   series, character, show, episode, characters, episodes, season, appeared, comics, original
#   created_by, television_series, a_fictional_character, first_appeared, based_on, portrayed_by
# Topic 33:
#   current, past, including, times, present, remains, date, created, holds, recently
#   has_been, have_been, as_well_as, since_then, also_been, due_to
# Topic 34:
#   time, made, back, end, making, move, place, set, point, rest
#   to_make, to_be, more_than, to_take, as_well, so_that
# Topic 35:
#   fame, played, player, coach, hall, named, selected, career, players, nba
#   is_an_american, national_basketball_association, head_coach, his_career, where_he, was_inducted_into
# Topic 36:
#   town, village, population, located, area, county, part, parish, municipality, north
#   2010_census, named_after, civil_parish, is_situated, 2011_census, 2000_census
# Topic 37:
#   god, religion, islam, religious, christian, jesus, muslims, islamic, muslim, christianity
#   according_to, based_on, new_testament, to_be, such_as, believed_to
# Topic 38:
#   government, president, head, minister, office, ministry, position, appointed, cabinet, post
#   prime_minister, responsible_for, was_appointed, headed_by, foreign_affairs, vice_president
# Topic 39:
#   magazine, media, published, newspaper, news, paper, website, press, editor, daily
#   published_by, new_york_times, according_to, focused_on, social_media, owned_by
# Topic 40:
#   community, township, pennsylvania, ohio, located, philadelphia, population, named, cleveland, part
#   united_states, new_jersey, is_an_unincorporated, post_office, 2010_census, 2000_census
# Topic 41:
#   won, title, final, championship, winning, reached, defeated, lost, win, titles
#   to_win, first_time, first_round, world_no, second_round, first_time_since
# Topic 42:
#   white, black, red, green, flag, blue, arms, color, brown, cross
#   to_represent, national_flag, also_known_as, reference_to, based_on, they_were
# Topic 43:
#   group, california, groups, nevada, based, berkeley, members, american, oakland, ca
#   los_angeles, san_francisco, united_states, san_diego, known_for, is_an_american
# Topic 44:
#   art, museum, work, works, collection, library, artist, arts, artists, painting
#   his_work, as_well_as, fine_arts, natural_history, inspired_by, national_museum
# Topic 45:
#   road, street, bridge, highway, route, section, avenue, neighborhood, north, runs
#   state_highway, passes_through, main_street, designated_as, state_route, east_side
# Topic 46:
#   kingdom, period, empire, roman, power, emperor, bc, rule, history, dynasty
#   middle_ages, ruled_by, roman_empire, ottoman_empire, byzantine_empire, 15th_century
# Topic 47:
#   oregon, american, including, portland, part, brooklyn, manhattan, buffalo, jamaica, rochester
#   new_york, new_york_city, united_states, is_an_american, an_american, long_island
# Topic 48:
#   australia, australian, victoria, sydney, melbourne, queensland, suburb, adelaide, perth, brisbane
#   new_south_wales, is_an_australian, western_australia, south_australia, an_australian, papua_new_guinea
# Topic 49:
#   book, published, author, books, works, writer, work, literature, story, writing
#   science_fiction, has_written, he_wrote, published_by, short_stories, his_work
# Topic 50:
#   development, project, program, health, support, environment, provide, resources, policy, projects
#   access_to, to_improve, to_promote, to_develop, to_create, health_care
# Topic 51:
#   typically, process, specific, person, generally, rules, individual, practice, provide, case
#   such_as, may_be, can_be, for_example, or_more, they_are
# Topic 52:
#   small, long, large, body, size, smaller, length, wood, called, similar
#   also_known_as, attached_to, also_called, can_be, could_be, to_create
# Topic 53:
#   house, members, council, parliament, elected, member, election, seat, assembly, representatives
#   legislative_assembly, national_assembly, legislative_council, lower_house, upper_house, general_election
# Topic 54:
#   team, played, football, teams, players, international, rugby, sport, competition, play
#   world_cup, national_team, rugby_union, they_have, is_controlled_by, national_football_team
# Topic 55:
#   march, january, october, early, april, september, june, august, december, november
#   that_year, followed_by, had_been, same_year, following_year, returned_to
# Topic 56:
#   term, terms, word, meaning, concept, form, means, generally, specific, applied
#   refers_to, such_as, to_refer_to, derived_from, refer_to, for_example
# Topic 57:
#   year, day, held, festival, days, events, years, date, night, beginning
#   each_year, every_year, gregorian_calendar, an_annual, takes_place, to_celebrate
# Topic 58:
#   world, history, including, greatest, oldest, major, global, ranked, worldwide, considered
#   has_been, as_well_as, more_than, all_time, considered_one, most_famous
# Topic 59:
#   church, christian, temple, catholic, churches, utah, mission, members, christ, religious
#   catholic_church, jesus_christ, roman_catholic, salt_lake_city, known_as, roman_catholic_church
# Topic 60:
#   spain, spanish, mexico, de, brazil, argentina, brazilian, chile, caribbean, mexican
#   puerto_rico, latin_america, south_america, buenos_aires, mexico_city, costa_rica
# Topic 61:
#   part, major, called, formed, minor, key, included, main, originally, principal
#   known_as, also_known_as, along_with, has_been, often_referred_to, or_simply
# Topic 62:
#   1980s, 1970s, 1990s, began, 1960s, 1950s, early, success, 1930s, continued
#   20th_century, early_1990s, late_1960s, late_1980s, early_1970s, late_1990s
# Topic 63:
#   island, bay, islands, sea, colorado, point, beach, coast, part, peninsula
#   new_mexico, pacific_ocean, atlantic_ocean, east_coast, an_area, west_coast
# Topic 64:
#   class, ship, ships, built, service, navy, uss, fleet, launched, commissioned
#   royal_navy, united_states_navy, launched_on, during_world_war, world_war_ii, named_after
# Topic 65:
#   season, team, nfl, game, playoffs, record, games, nhl, franchise, played
#   national_football_league, national_hockey_league, regular_season, super_bowl, he_played_college, former_american_football
# Topic 66:
#   john, david, michael, paul, robert, wilson, bell, mark, miller, thompson
#   is_an_american, best_known_for, is_best_known, known_for, has_worked, also_worked
# Topic 67:
#   film, films, theatre, actor, director, movie, actress, television, producer, role
#   directed_by, is_an_american, produced_by, based_on, was_nominated_for, same_name
# Topic 68:
#   club, played, season, manager, side, league, appearances, goals, liverpool, playing
#   football_league, fa_cup, premier_league, manchester_united, who_played, where_he
# Topic 69:
#   fire, caused, people, occurred, damage, storm, killed, deaths, hurricane, time
#   due_to, at_least, there_were, caused_by, tropical_storm, more_than
# Topic 70:
#   energy, water, power, material, form, ice, gas, process, heat, temperature
#   such_as, can_be, to_produce, natural_gas, can_also, also_called
# Topic 71:
#   age, time, years, life, made, young, jones, early, started, working
#   along_with, to_become, two_years, an_early, three_years, moved_to
# Topic 72:
#   king, son, duke, prince, charles, henry, title, william, lord, house
#   his_father, his_son, until_his_death, was_succeeded_by, his_death, his_brother
# Topic 73:
#   game, released, games, series, version, features, original, release, development, versions
#   based_on, developed_by, published_by, video_game, video_games, such_as
# Topic 74:
#   won, record, gold, silver, held, contest, competition, winning, set, championships
#   gold_medal, world_championships, bronze_medal, to_win, silver_medal, most_successful
# Topic 75:
#   family, children, married, child, daughter, mother, marriage, wife, father, queen
#   was_born, his_wife, her_husband, where_she, her_father, they_had
# Topic 76:
#   japan, japanese, europe, world, asia, born, tokyo, korea, including, korean
#   north_america, south_korea, also_known_as, as_well_as, known_as, has_been
# Topic 77:
#   washington, georgia, virginia, alabama, louisiana, indiana, mississippi, columbia, seattle, atlanta
#   united_states, north_carolina, south_carolina, new_orleans, west_virginia, george_washington
# Topic 78:
#   airport, port, aircraft, air, base, located, largest, flight, passengers, international
#   international_airport, operated_by, serves_as, royal_air_force, as_well_as, formerly_known_as
# Topic 79:
#   original, system, created, changed, introduced, replaced, originally, added, separate, initially
#   prior_to, replaced_by, was_renamed, had_been, was_replaced_by, along_with
# Topic 80:
#   james, smith, george, john, martin, scott, taylor, jack, joe, tom
#   an_american, best_known_for, is_an_american, his_brother, who_worked, other_notable
# Topic 81:
#   man, made, great, johnson, good, called, time, big, famous, popular
#   known_for, his_own, most_famous, well_known, to_keep, man_who
# Topic 82:
#   north, south, west, east, located, area, northwest, northeast, southwest, border
#   it_is_bordered, is_bounded_by, is_bordered_by, as_far, an_area, southern_part
# Topic 83:
#   law, act, constitution, laws, government, rights, legal, states, bill, passed
#   human_rights, federal_government, accordance_with, approved_by, international_law, to_protect
# Topic 84:
#   disease, treatment, blood, body, medical, people, cells, include, cancer, human
#   such_as, also_known_as, may_be, associated_with, due_to, caused_by
# Topic 85:
#   river, lake, water, valley, mountain, mountains, range, rivers, area, creek
#   national_park, mountain_range, national_forest, state_park, named_after, red_river
# Topic 86:
#   union, general, tennessee, lee, rose, jackson, grant, end, position, memphis
#   american_civil_war, along_with, civil_war, served_as, to_become, prior_to
# Topic 87:
#   state, department, states, federal, commonwealth, idaho, governor, montana, secretary, wyoming
#   north_dakota, south_dakota, responsible_for, united_states, united_states_department, federal_government
# Topic 88:
#   government, independence, country, republic, afghanistan, led, power, revolution, war, support
#   united_nations, led_by, civil_war, democratic_republic, two_countries, relations_with
# Topic 89:
#   political, movement, social, society, freedom, economic, groups, politics, people, cultural
#   such_as, human_rights, based_on, civil_rights, focused_on, rather_than
# Topic 90:
#   london, england, oxford, birmingham, kent, cambridge, bristol, english, surrey, essex
#   was_an_english, united_kingdom, an_english, london_borough, south_west, river_thames
# Topic 91:
#   english, language, languages, written, names, standard, words, latin, spoken, modern
#   derived_from, such_as, based_on, spoken_by, official_language, english_language
# Topic 92:
#   florida, michigan, named, detroit, williams, kansas, alaska, miami, member, bush
#   united_states, is_an_american, is_best_known, as_well_as, an_american, served_as
# Topic 93:
#   party, election, leader, seats, won, held, elections, vote, majority, government
#   political_party, led_by, general_election, liberal_party, labour_party, democratic_party
# Topic 94:
#   data, software, systems, system, computer, information, microsoft, internet, support, technology
#   such_as, operating_system, based_on, developed_by, operating_systems, can_be
# Topic 95:
#   died, member, born, son, william, age, john, thomas, worked, director
#   was_born, where_he, he_died, was_appointed, he_worked, his_life
# Topic 96:
#   italy, italian, diocese, bishop, cathedral, rome, part, milan, abbey, city
#   an_italian, dedicated_to, serie_a, roman_catholic_diocese, roman_catholic_church, roman_catholic_archdiocese
# Topic 97:
#   bank, money, market, price, banks, financial, exchange, property, sale, tax
#   real_estate, central_bank, stock_exchange, national_bank, to_buy, financial_services
# Topic 98:
#   texas, stadium, home, center, located, arena, opened, capacity, field, houston
#   moved_to, san_antonio, formerly_known_as, owned_by, operated_by, also_hosted
# Topic 99:
#   song, single, released, number, featured, version, included, recorded, performed, video
#   written_by, produced_by, billboard_hot_100, uk_singles_chart, music_video, top_ten
# Topic 100:
#   played, play, game, test, ball, match, cricket, lead, players, runs
#   west_indies, who_played, county_championship, to_take, cricket_club, he_scored
# Topic 101:
#   season, team, record, games, played, baseball, game, series, al, franchise
#   national_league, world_series, major_league_baseball, american_league, new_york_yankees, major_league
# Topic 102:
#   division, fourth, place, arizona, total, ten, top, 2nd, seventh, sixth
#   first_time, along_with, prior_to, tied_for, top_three, one_point
# Topic 103:
#   main, part, including, local, portugal, portuguese, made, hamilton, included, ring
#   new_zealand, known_as, as_well_as, due_to, they_were, commonly_known_as
# Topic 104:
#   national, association, members, member, organization, founded, international, federation, society, organisation
#   affiliated_with, a_founding_member, an_independent, scout_movement, formerly_known_as, governing_body
# Topic 105:
#   region, province, area, regions, areas, provinces, territory, capital, cities, municipalities
#   an_area, divided_into, local_government, there_are, defined_by, administered_by
# Topic 106:
#   elected, governor, president, member, representatives, republican, house, senate, congress, office
#   he_served_as, served_as, united_states_house, vice_president, he_served, to_serve
# Topic 107:
#   number, list, including, iran, included, numbers, total, hawaii, code, call
#   based_on, according_to, also_known_as, as_well_as, has_been, more_than
# Topic 108:
#   canada, canadian, ontario, toronto, quebec, province, alberta, montreal, vancouver, manitoba
#   british_columbia, nova_scotia, new_brunswick, legislative_assembly, canadian_province, prince_edward_island
# Topic 109:
#   world, economy, country, largest, industry, agriculture, trade, production, oil, major
#   according_to, second_largest, economic_growth, more_than, world_bank, natural_resources
# Topic 110:
#   high, low, increased, level, increase, higher, rate, lack, average, levels
#   due_to, compared_to, expected_to, to_be, ability_to, at_least
# Topic 111:
#   system, set, function, unit, method, problem, point, mathematics, object, values
#   for_example, can_be, based_on, defined_as, an_object, may_be
# Topic 112:
#   court, case, justice, judge, prison, trial, murder, police, courts, crime
#   supreme_court, chief_justice, had_been, was_arrested, high_court, charged_with
# Topic 113:
#   company, founded, corporation, companies, sold, brand, business, products, subsidiary, largest
#   owned_by, merged_with, was_acquired_by, purchased_by, brand_name, listed_on
# Topic 114:
#   award, received, awarded, awards, won, year, national, presented, prize, academy
#   have_won, has_been, known_for, for_his_work, each_year, that_year
# Topic 115:
#   games, sports, events, sport, athletes, held, event, total, compete, competed
#   olympic_games, competed_at, first_time, were_held, took_part, 2008_summer_olympics
# Topic 116:
#   line, station, railway, service, lines, opened, trains, served, services, stations
#   railway_station, operated_by, main_line, public_transport, railway_line, it_serves
# Topic 117:
#   england, scotland, wales, scottish, english, welsh, manchester, glasgow, leeds, edinburgh
#   united_kingdom, north_west, greater_manchester, west_yorkshire, great_britain, north_east
# Topic 118:
#   album, band, released, records, release, recorded, albums, songs, label, group
#   is_an_american, rock_band, all_time, record_producer, billboard_200, record_label
# Topic 119:
#   building, built, buildings, construction, house, tower, located, architecture, completed, houses
#   designed_by, city_hall, town_hall, to_build, were_built, historic_district
# Topic 120:
#   sweden, philippines, norway, part, denmark, swedish, national, finland, norwegian, danish
#   as_well_as, has_been, also_known_as, along_with, together_with, faroe_islands
# Topic 121:
#   club, league, season, division, teams, clubs, football, team, founded, based
#   football_club, football_league, second_division, have_won, premier_league, they_play
# Topic 122:
#   county, maryland, population, kentucky, properties, districts, counties, named, arkansas, list
#   national_register, 2010_census, united_states, historic_places, county_located, its_county_seat
# Topic 123:
#   left, end, began, lost, joined, remained, return, continued, eventually, back
#   had_been, returned_to, who_had, they_were, to_become, this_time
# Topic 124:
#   order, considered, called, time, made, thought, earlier, complete, proved, superior
#   to_be, they_were, known_as, according_to, have_been, to_make
# Topic 125:
#   species, food, found, family, animals, native, fish, tree, plant, plants
#   such_as, they_are, have_been, years_ago, derived_from, ranging_from
# Topic 126:
#   tournament, held, final, competition, won, played, event, championship, cup, open
#   ended_on, took_place, singles_title, defending_champions, took_place_at, played_on_outdoor
# Topic 127:
#   study, research, science, field, theory, philosophy, development, studies, fields, work
#   concerned_with, deals_with, to_understand, focused_on, based_on, nobel_prize

# %% [markdown]
# ## 3. Build Similarity Index
#
# - [Similarity Queries](https://radimrehurek.com/gensim/tut3.html)

# %%
# %%time

vectors = lda[encoded_corpus]
index = similarities.MatrixSimilarity(vectors)

index.save(SIMILARITY_INDEX_PATH)
# Out:
# CPU times: user 10min 26s, sys: 2.92 s, total: 10min 29s
# Wall time: 2min 38s

# %%
index = similarities.MatrixSimilarity.load(SIMILARITY_INDEX_PATH)

# %% [markdown]
# ## 4 Build Entity Linker

# %%
class EntityLinker(object):
    def __init__(
        self, 
        directory=MODEL_DIRECTORY,
        similarity_threshold=0.6,
        n_suggestions=7

    ):
        path = os.path.join(directory, 'dictionary.pkl')
        self.dictionary = Dictionary.load(path)   
        
        path = os.path.join(directory, 'gensim.model')
        self.model = LdaMallet.load(path)
        
        path = os.path.join(directory, 'similarity.index')
        self.index = similarities.MatrixSimilarity.load(path)
        
        self.bigram_phraser, self.trigram_phraser = load_phrasers(directory)
        
        self.similarity_threshold = similarity_threshold
        self.n_suggestions = n_suggestions


    def tokenize(self, text):
        return [token.lower() for token in word_tokenize(text)]

    def __call__(self, text):
        text = clean(text)
        tokens = self.tokenize(text)
        tokens = self.bigram_phraser[tokens]
        tokens = self.trigram_phraser[tokens]
        bow = self.dictionary.doc2bow(tokens)
        vector = self.model[bow]
        sims = self.index[vector]
        sims = enumerate(sims)
        sims = sorted(sims, key=lambda item:-item[-1])
        suggestions = []
        cnt = 0
        seen = set([])
        for i, sim in sims:
            title, summary = records[i][0], records[i][1]
            #print("%d. [%0.2f] %s/%s" % (cnt + 1, sim, cat, subcat))
            if cnt > 0 and (cnt >= self.n_suggestions or sim < self.similarity_threshold): break
            if title in seen: continue
            cnt += 1
            seen.add(title)
            suggestions.append((sim, title, summary))
        return suggestions

linker = EntityLinker(similarity_threshold=0.6, n_suggestions=7)

# %%
N = 200
indices = range(len(records))

# %%
index = random.choice(indices)
title, context = records[index]
print("[%d] %s: %s" % (index, title, context[:N]))
for sim, title, summary in linker(context):
    print("[%0.2f] %s\n%s" % (sim, title, summary[:N]))
# Out:
# [102722] Peer Nielsen: Peer Nielson (sometimes shown as Peer Noorbohm, born June 25, 1942) is a Danish sprint canoer who competed in the early 1960s. He won the bronze medal in the C-2 1000 m event at the 1964 Summer Olympi
# [1.00] Peer Nielsen
# Peer Nielson (sometimes shown as Peer Noorbohm, born June 25, 1942) is a Danish sprint canoer who competed in the early 1960s. He won the bronze medal in the C-2 1000 m event at the 1964 Summer Olympi
# [0.82] Hans Nilsson (canoeist)
# Hans Nilsson (born September 5, 1946) is a Swedish sprint canoer who competed in the late 1960s and early 1970s. He won a bronze medal in the K-4 10000 m event at the 1970 ICF Canoe Sprint World Champ
# [0.82] Petra Tierlich
# Petra Tierlich, born 25 February 1945, is an East German luger who competed in the 1960s. She won three medals in the women's singles event at the FIL World Luge Championships with a gold in 1969 and
# [0.79] Ingela Ericsson
# Ingela Ericsson (born September 27, 1968) is a Swedish sprint canoer who competed from the mid-1990s to the early 2000s (decade). Competing in two Summer Olympics, she won a bronze medal in the K-4 50
# [0.78] Birgitta Larsson
# Birgitta Larsson (born 4 October 1941) is a Swedish orienteering competitor. She won two world titles as a member of Swedish relay teams in 1970 and 1974; in 1972 she won an individual bronze and a te
# [0.77] Miss Universe 1974
# Miss Universe 1974, the 23rd Miss Universe pageant, was held on 21 July 1974 at the Folk Arts Theater in Manila, Philippines. It was the first time in the pageant's history that the event was held in
# [0.77] Petra Setzkorn
# Petra Setzkorn is an East German sprint canoer who competed in the early 1970s. She won six medals at the ICF Canoe Sprint World Championships with two silvers (K-2 500 m: 1971, K-4 500 m: 1970) and f

# %%
context = "Before she joined the US Senate, Amy Klobuchar spent much of her career locking people up as the prosecutor for Hennepin County, Minnesota. But if she’s elected president, the Democrat has vowed to enact reforms within a month that could free thousands, if not tens of thousands, of people from federal prisons — and she won’t even need Congress to do it.".strip()
#context = "And now Klobuchar wants to use that power, much as President Barack Obama did toward the end of his term, to roll back mass incarceration and the war on drugs. By setting up a new system for clemency as soon as possible, she aims to release thousands of people with overly long prison sentences who’ve shown signs of rehabilitation."
for sim, title, summary in linker(context):
    print("[%0.2f] %s\n%s" % (sim, title, summary[:N]))
# Out:
# [0.74] Hurricane Diana
# Hurricane Diana was the deadliest tropical cyclone during the 1990 Atlantic hurricane season, killing 139 people in Mexico. Forming out of a tropical wave on August 4, the system brushed Honduras befo
# [0.74] Hurricane Karen (2007)
# Hurricane Karen was the eleventh named storm and fourth hurricane of the 2007 Atlantic hurricane season. Karen was a Cape Verde-type hurricane that developed in the eastern tropical Atlantic out of a
# [0.72] Hurricane Iris (1995)
# Hurricane Iris was the first of three tropical cyclones to affect the Lesser Antilles in a three-week period, preceding the more destructive hurricanes Luis and Marilyn. The ninth named storm and fift
# [0.72] 2001 Atlantic hurricane season
# The 2001 Atlantic hurricane season was a fairly active Atlantic hurricane season that produced 17 tropical cyclones, 15 named storms, nine hurricanes, and four major hurricanes. The season officially
# [0.72] 2004 Atlantic hurricane season
# The 2004 Atlantic hurricane season was a very deadly, destructive, and hyperactive Atlantic hurricane season, with over 3,200 deaths and more than $61 billion (2004 USD) in damage. More than half of t
# [0.72] Cyclone Nancy
# Cyclone Nancy (RSMC Nadi designation: 09F, JTWC designation: 18P) was the second in a series of four severe tropical cyclones to impact the Cook Islands during February 2005. Forming out of an area of
# [0.72] 1992 Erzincan earthquake
# On 13 March, the 1992 Erzincan earthquake struck eastern Turkey with a moment magnitude of 6.7 and a maximum Mercalli intensity of VIII (Severe). Originating on the North Anatolian Fault, it rocked th
